# %% [markdown]
# <a href="https://colab.research.google.com/github/Jming9638/MachineLearning/blob/main/IdendityResolutionV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install recordlinkage
# Out:
# Collecting recordlinkage
#   Downloading recordlinkage-0.16-py3-none-any.whl (926 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.9/926.9 kB 16.6 MB/s eta 0:00:00
# Collecting jellyfish>=1 (from recordlinkage)
#   Downloading jellyfish-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from recordlinkage) (1.23.5)
# Requirement already satisfied: pandas<3,>=1 in /usr/local/lib/python3.10/dist-packages (from recordlinkage) (1.5.3)
# Requirement already satisfied: scipy>=1 in /usr/local/lib/python3.10/dist-packages (from recordlinkage) (1.11.4)
# Requirement already satisfied: scikit-learn>=1 in /usr/local/lib/python3.10/dist-packages (from recordlinkage) (1.2.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from recordlinkage) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1->recordlinkage) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1->recordlinkage) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1->recordlinkage) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<3,>=1->recordlinkage) (1.16.0)
# Installing collected packages: jellyfish, recordlinkage
# Successfully installed jellyfish-1.0.3 recordlinkage-0.16

# %%
import pandas as pd
import numpy as np
import string
import recordlinkage

from recordlinkage.preprocessing import clean, phonetic
from recordlinkage.index import Full

# %%
def process_text(text):
    text = str(text)
    lower_text = text.lower()
    no_punctuation_text = lower_text.translate(str.maketrans('', '', string.punctuation))
    final_text = no_punctuation_text.replace(' ', '')
    return final_text

# %%
from google.oauth2 import service_account
credentials = service_account.Credentials.from_service_account_file('./bq-service-account.json')

# %%
from google.cloud import bigquery

client = bigquery.Client(credentials=credentials)

query = """
SELECT *
FROM `spheric-terrain-312804.identity_resolution_us.active_us`
"""
df_active = client.query(query).to_dataframe()

query = """
SELECT *
FROM `spheric-terrain-312804.identity_resolution_us.shopify_us`
"""
df_shopify = client.query(query).to_dataframe()

# %%
data = pd.concat([df_active, df_shopify], ignore_index=True)
data = data.drop(['gender', 'age'], axis=1)
data.head()
# Out:
#               uuid first_name last_name            phone  \
# 0  active_0b7b5536        Rob       Lee     +16411050868
# 1  active_901edfb3       Cris    Farmer     +13085813884
# 2  active_367942c8       Kena     Pitts  +1-313-369-1737
# 3  active_05a04ef9       Nick   Schmidt  +1-240-538-2219
# 4  active_6df8da1a       Otha      Page  +1-325-108-4701
#
#                         email                 address  zipcode  \
# 0         rna1920@outlook.com     1268 Vallejo Center    47239
# 1  engines1936@protonmail.com       482 Thor Junction    30644
# 2        locally1869@duck.com   241 Forest Knolls Run    76761
# 3     reasonable1977@duck.com  543 Crissy Field Plaza    39556
# 4         emily1888@yahoo.com        190 Skyview Lake    31847
#
#         post_Town         state    country region continent
# 0    Bloomingdale        Kansas      Nauru   Iowa      Asia
# 1        Lawndale     Tennessee   Dominica   Iowa      Asia
# 2  Cuyahoga Falls          Utah  Guatemala   Iowa      Asia
# 3      Plant City  South Dakota     Norway   Iowa      Asia
# 4          Lowell     Louisiana     Jersey   Iowa      Asia

# %%
for col in data.columns:
    if col != 'uuid':
        if col != 'email':
            data[col] = data[col].apply(process_text)
        else:
            data[col] = data[col].apply(lambda x: str(x).split('@')[0])
            data[col] = data[col].apply(process_text)

# %%
def fast_recordlinkage(data, required_cols):
    data = data.set_index('uuid')
    data1 = data.copy()
    data2 = data.copy()

    print('Total iterations:', data1.shape[0] * data2.shape[0] * len(required_cols))

    indexer = recordlinkage.Index()
    indexer.add(Full())
    candidate_links = indexer.index(data1, data1)

    compare = recordlinkage.Compare(n_jobs=-1)
    for feature in required_cols:
        if feature not in ['phone', 'zipcode']:
            compare.string(feature, feature, method='jarowinkler', label=feature)
        else:
            compare.string(feature, feature, method='levenshtein', label=feature)

    matches = compare.compute(candidate_links, data1, data2)
    matches.columns = [x + '_score' for x in matches.columns]
    matches = matches.reset_index()
    data1 = data1.reset_index()
    data2 = data2.reset_index()
    data1.columns = [c + '_1' for c in data1.columns]
    data2.columns = [c + '_2' for c in data2.columns]

    matches = matches.merge(data1, on='uuid_1', how='left')
    matches = matches.merge(data2, on='uuid_2', how='left')
    matches = matches.set_index(['uuid_1', 'uuid_2'])
    matches = matches[sorted(matches.columns)]
    matches['matching_rate'] = matches[[s for s in matches.columns if '_score' in s]].mean(axis=1)

    return matches

# %%
required_cols = [col for col in data.columns if col != 'uuid']
matches = fast_recordlinkage(data.sample(frac=0.1, random_state=42), required_cols)
# Out:
# Total iterations: 29802476
# WARNING:recordlinkage:indexing - performance warning - A full index can result in large number of record pairs.
# WARNING:recordlinkage:indexing - performance warning - A full index can result in large number of record pairs.

# %%
matches
# Out:
#                                            address_1           address_2  \
# uuid_1          uuid_2
# active_574e71d3 active_574e71d3         266fargomews        266fargomews
#                 active_c683f603         266fargomews      1226emerytrail
#                 shopify_8a754252        266fargomews      921lestercreek
#                 shopify_f90999a9        266fargomews     1310hofflanding
#                 active_9a242cf8         266fargomews  677mccoppinstation
# ...                                              ...                 ...
# active_d0d7fa34 active_582c539c   695armisteadstreet    1215mayfaircourt
#                 active_69bc7e23   695armisteadstreet    1357robbleefield
#                 active_b36e7814   695armisteadstreet  430santamonicapark
#                 shopify_9882a192  695armisteadstreet  1125acevedoviaduct
#                 active_d0d7fa34   695armisteadstreet  695armisteadstreet
#
#                                   address_score continent_1 continent_2  \
# uuid_1          uuid_2
# active_574e71d3 active_574e71d3        1.000000        asia        asia
#                 active_c683f603        0.524603        asia   australia
#                 shopify_8a754252       0.456349        asia  antarctica
#                 shopify_f90999a9       0.372222        asia  antarctica
#                 active_9a242cf8        0.435185        asia  antarctica
# ...                                         ...         ...         ...
# active_d0d7fa34 active_582c539c        0.523148        asia   australia
#                 active_69bc7e23        0.561177        asia  antarctica
#                 active_b36e7814        0.449735        asia   australia
#                 shopify_9882a192       0.546296        asia      africa
#                 active_d0d7fa34        1.000000        asia        asia
#
#                                   continent_score   country_1  \
# uuid_1          uuid_2
# active_574e71d3 active_574e71d3          1.000000        chad
#                 active_c683f603          0.694444        chad
#                 shopify_8a754252         0.566667        chad
#                 shopify_f90999a9         0.566667        chad
#                 active_9a242cf8          0.566667        chad
# ...                                           ...         ...
# active_d0d7fa34 active_582c539c          0.694444  puertorico
#                 active_69bc7e23          0.566667  puertorico
#                 active_b36e7814          0.694444  puertorico
#                 shopify_9882a192         0.775000  puertorico
#                 active_d0d7fa34          1.000000  puertorico
#
#                                                country_2  country_score  \
# uuid_1          uuid_2
# active_574e71d3 active_574e71d3                     chad       1.000000
#                 active_c683f603                    japan       0.483333
#                 shopify_8a754252            ålandislands       0.555556
#                 shopify_f90999a9               lithuania       0.574074
#                 active_9a242cf8                   monaco       0.472222
# ...                                                  ...            ...
# active_d0d7fa34 active_582c539c                 ethiopia       0.550000
#                 active_69bc7e23                  stlucia       0.490476
#                 active_b36e7814   palestinianterritories       0.625108
#                 shopify_9882a192                 bahrain       0.495238
#                 active_d0d7fa34               puertorico       1.000000
#
#                                         email_1  ...  region_1       region_2  \
# uuid_1          uuid_2                           ...
# active_574e71d3 active_574e71d3   miniature1991  ...  michigan       michigan
#                 active_c683f603   miniature1991  ...  michigan     california
#                 shopify_8a754252  miniature1991  ...  michigan    rhodeisland
#                 shopify_f90999a9  miniature1991  ...  michigan    northdakota
#                 active_9a242cf8   miniature1991  ...  michigan       oklahoma
# ...                                         ...  ...       ...            ...
# active_d0d7fa34 active_582c539c       scary1925  ...  oklahoma   newhampshire
#                 active_69bc7e23       scary1925  ...  oklahoma       kentucky
#                 active_b36e7814       scary1925  ...  oklahoma         hawaii
#                 shopify_9882a192      scary1925  ...  oklahoma  northcarolina
#                 active_d0d7fa34       scary1925  ...  oklahoma       oklahoma
#
#                                  region_score      state_1      state_2  \
# uuid_1          uuid_2
# active_574e71d3 active_574e71d3      1.000000  rhodeisland  rhodeisland
#                 active_c683f603      0.575000  rhodeisland     kentucky
#                 shopify_8a754252     0.537879  rhodeisland    tennessee
#                 shopify_f90999a9     0.477273  rhodeisland  connecticut
#                 active_9a242cf8      0.333333  rhodeisland     virginia
# ...                                       ...          ...          ...
# active_d0d7fa34 active_582c539c      0.430556        maine         ohio
#                 active_69bc7e23      0.416667        maine  mississippi
#                 active_b36e7814      0.430556        maine  southdakota
#                 shopify_9882a192     0.603205        maine    newmexico
#                 active_d0d7fa34      1.000000        maine        maine
#
#                                  state_score zipcode_1  zipcode_2  \
# uuid_1          uuid_2
# active_574e71d3 active_574e71d3     1.000000     56744      56744
#                 active_c683f603     0.405303     56744      26984
#                 shopify_8a754252    0.468013     56744      60714
#                 shopify_f90999a9    0.515152     56744      33647
#                 active_9a242cf8     0.454545     56744      33116
# ...                                      ...       ...        ...
# active_d0d7fa34 active_582c539c     0.483333     37866      76012
#                 active_69bc7e23     0.527273     37866      70125
#                 active_b36e7814     0.000000     37866      95509
#                 shopify_9882a192    0.533333     37866      42390
#                 active_d0d7fa34     1.000000     37866      37866
#
#                                  zipcode_score matching_rate
# uuid_1          uuid_2
# active_574e71d3 active_574e71d3            1.0      1.000000
#                 active_c683f603            0.4      0.479491
#                 shopify_8a754252           0.4      0.424396
#                 shopify_f90999a9           0.2      0.451623
#                 active_9a242cf8            0.0      0.342529
# ...                                        ...           ...
# active_d0d7fa34 active_582c539c            0.0      0.407799
#                 active_69bc7e23            0.0      0.389989
#                 active_b36e7814            0.0      0.363292
#                 shopify_9882a192           0.0      0.519112
#                 active_d0d7fa34            1.0      1.000000
#
# [2709316 rows x 34 columns]

# %%
matches = matches.reset_index()
filters = (matches['matching_rate'] > 0.4)
deduped_data = matches[filters].reset_index(drop=True)
deduped_data


def aggregate_to_list(series):
    return list(series)


grouped_id = deduped_data.groupby(['uuid_1']).agg({'uuid_2': aggregate_to_list}).reset_index()


def merge_columns(row):
    return sorted(list(set([row['uuid_1']] + row['uuid_2'])))


grouped_id['merged'] = grouped_id.apply(merge_columns, axis=1)
grouped_id.drop_duplicates(subset=['merged'])
# Out:
#                 uuid_1                                             uuid_2  \
# 0      active_008b0a62  [active_574e71d3, shopify_f90999a9, active_9a2...
# 1      active_00f57040  [active_c683f603, shopify_8a754252, active_9a2...
# 2      active_011129ce  [active_c683f603, active_9a242cf8, shopify_cd4...
# 3      active_0148eeba  [shopify_8a754252, active_9a242cf8, active_f4a...
# 4      active_01c9ad28  [active_c683f603, shopify_f90999a9, active_9a2...
# ...                ...                                                ...
# 1641  shopify_fe7fab58  [active_574e71d3, active_c683f603, shopify_8a7...
# 1642  shopify_feef5707  [active_574e71d3, active_c683f603, shopify_cd4...
# 1643  shopify_ffa7bf61  [active_c683f603, shopify_8a754252, shopify_f9...
# 1644  shopify_ffd5d509  [active_574e71d3, shopify_8a754252, shopify_f9...
# 1645  shopify_ffd91484  [shopify_f90999a9, active_9a242cf8, active_537...
#
#                                                  merged
# 0     [active_008b0a62, active_00f57040, active_0111...
# 1     [active_008b0a62, active_00f57040, active_01c9...
# 2     [active_008b0a62, active_011129ce, active_0148...
# 3     [active_008b0a62, active_011129ce, active_0148...
# 4     [active_00f57040, active_011129ce, active_01c9...
# ...                                                 ...
# 1641  [active_008b0a62, active_00f57040, active_0111...
# 1642  [active_008b0a62, active_00f57040, active_0111...
# 1643  [active_00f57040, active_0148eeba, active_01c9...
# 1644  [active_008b0a62, active_011129ce, active_0148...
# 1645  [active_008b0a62, active_00f57040, active_0111...
#
# [1636 rows x 3 columns]
